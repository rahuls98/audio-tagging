# %% [markdown]
# ### Preprocessing parameters
# <hr>
#
# - sampling_rate = 22050
# - hop_length = 256
# - duration = 5
# - n_mels = 96
# - nfft = 512
#
# Clips with length less than 5 seconds were padded using 'wrap' and 'constant'.<br>
# Data augmentation was performed to increase dataset size.
#
# <hr>

# %% [markdown]
# ### Model

# %%
import os
os.listdir('/kaggle/input')
# Out:
# ['esc-animalsounds']

# %%
for dirname, _, filenames in os.walk('/kaggle/input/esc-animalsounds'):
    c = 0
    for filename in filenames:
        c += 1
        
    if c>0: 
        print("{} : {} images".format(dirname,c))
        print("--------------")
# Out:
# /kaggle/input/esc-animalsounds/animal_sounds/Cat : 53 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Dog : 56 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Crow : 50 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Insects : 43 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Pig : 47 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Cow : 48 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Chirping birds : 41 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Crickets : 40 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Frog : 41 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Hen : 46 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Sheep : 42 images
# --------------
# /kaggle/input/esc-animalsounds/animal_sounds/Rooster : 76 images
# --------------

# %%
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
class SmallerVGGNet:
    @staticmethod
    def build(width, height, depth, classes, finalAct):
        # initialize the model along with the input shape to be
        # "channels last" and the channels dimension itself
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = -1
        # if we are using "channels first", update the input shape
        # and channels dimension
        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)
            chanDim = 1
            
        # CONV => RELU => POOL
        model.add(Conv2D(32, (3, 3), padding="same", input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(3, 3)))
        model.add(Dropout(0.25))
        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(128, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(128, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        # first set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation("relu"))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))
        # sigmoid activation for multi-label classification
        model.add(Dense(classes))
        model.add(Activation(finalAct))
        # return the constructed network architecture
        return model

# %%
import matplotlib
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import pickle
import cv2
import os

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 30
IMAGE_DIMS = (150, 200, 3)

# %%
imagePaths = []
for dirname, _, filenames in os.walk(r'/kaggle/input/esc-animalsounds/'):
    for filename in filenames:
        imagePaths.append(os.path.join(dirname, filename))
        
imagePaths = sorted(imagePaths)
random.seed(42)
random.shuffle(imagePaths)

# %%
image = imagePaths[4]
image = cv2.imread(image)
image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))
plt.show()

# %%
data = []
labels = []

for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data.append(image)
    
    l = label = imagePath.split(os.path.sep)[-2]
    labels.append((l,))
    
labels[0:5]
# Out:
# [('Pig',), ('Sheep',), ('Insects',), ('Sheep',), ('Pig',)]

# %%
print(len(data))
print(len(labels))
# Out:
# 583
# 583

# %%
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
mlb = MultiLabelBinarizer()
labels = mlb.fit_transform(labels)

print(len(mlb.classes_))
print(mlb.classes_)
# Out:
# 12
# ['Cat' 'Chirping birds' 'Cow' 'Crickets' 'Crow' 'Dog' 'Frog' 'Hen'
#  'Insects' 'Pig' 'Rooster' 'Sheep']

# %%
(train_X, valid_X, train_y, valid_y) = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
model = SmallerVGGNet.build(
    width=IMAGE_DIMS[1], height=IMAGE_DIMS[0],
    depth=IMAGE_DIMS[2], classes=len(mlb.classes_),
    finalAct="sigmoid"
)

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

model.compile(loss="binary_crossentropy", optimizer=opt,
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 150, 200, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 150, 200, 32)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 150, 200, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 66, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 66, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 66, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 50, 66, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 66, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 66, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 50, 66, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 50, 66, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 33, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25, 33, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 33, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 25, 33, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 25, 33, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 33, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 25, 33, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 25, 33, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 16, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 24576)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              25166848
# _________________________________________________________________
# activation_6 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                12300
# _________________________________________________________________
# activation_7 (Activation)    (None, 12)                0
# =================================================================
# Total params: 25,462,668
# Trainable params: 25,459,788
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
fit_results = model.fit(
    train_X, train_y,
    epochs = EPOCHS,
    batch_size = BS,
    validation_data = (valid_X, valid_y),
    verbose=1
)
# Out:
# Train on 466 samples, validate on 117 samples
# Epoch 1/100
# 466/466 [==============================] - 7s 16ms/step - loss: 0.8502 - accuracy: 0.5612 - val_loss: 0.6442 - val_accuracy: 0.6852
# Epoch 2/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.6843 - accuracy: 0.6429 - val_loss: 0.5512 - val_accuracy: 0.7842
# Epoch 3/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.5470 - accuracy: 0.7427 - val_loss: 0.6091 - val_accuracy: 0.9145
# Epoch 4/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.4292 - accuracy: 0.8196 - val_loss: 1.4010 - val_accuracy: 0.9167
# Epoch 5/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.2893 - accuracy: 0.9002 - val_loss: 2.0867 - val_accuracy: 0.9167
# Epoch 6/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.2062 - accuracy: 0.9354 - val_loss: 2.5411 - val_accuracy: 0.9167
# Epoch 7/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.1356 - accuracy: 0.9592 - val_loss: 1.6017 - val_accuracy: 0.9167
# Epoch 8/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.1064 - accuracy: 0.9710 - val_loss: 0.8453 - val_accuracy: 0.9167
# Epoch 9/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0825 - accuracy: 0.9776 - val_loss: 0.5248 - val_accuracy: 0.9167
# Epoch 10/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0639 - accuracy: 0.9818 - val_loss: 0.3803 - val_accuracy: 0.9167
# Epoch 11/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0506 - accuracy: 0.9873 - val_loss: 0.3866 - val_accuracy: 0.9167
# Epoch 12/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0402 - accuracy: 0.9923 - val_loss: 0.3891 - val_accuracy: 0.9174
# Epoch 13/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0319 - accuracy: 0.9945 - val_loss: 0.4035 - val_accuracy: 0.9174
# Epoch 14/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0282 - accuracy: 0.9952 - val_loss: 0.3915 - val_accuracy: 0.9181
# Epoch 15/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0243 - accuracy: 0.9966 - val_loss: 0.3821 - val_accuracy: 0.9167
# Epoch 16/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0197 - accuracy: 0.9971 - val_loss: 0.4206 - val_accuracy: 0.9152
# Epoch 17/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9977 - val_loss: 0.4310 - val_accuracy: 0.9209
# Epoch 18/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0144 - accuracy: 0.9984 - val_loss: 0.4488 - val_accuracy: 0.9224
# Epoch 19/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.4489 - val_accuracy: 0.8910
# Epoch 20/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0132 - accuracy: 0.9986 - val_loss: 0.4194 - val_accuracy: 0.9074
# Epoch 21/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.4014 - val_accuracy: 0.9124
# Epoch 22/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0087 - accuracy: 0.9995 - val_loss: 0.3761 - val_accuracy: 0.9174
# Epoch 23/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.3752 - val_accuracy: 0.9202
# Epoch 24/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.3726 - val_accuracy: 0.9209
# Epoch 25/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.9995 - val_loss: 0.3501 - val_accuracy: 0.9224
# Epoch 26/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.3200 - val_accuracy: 0.9259
# Epoch 27/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 0.3088 - val_accuracy: 0.9209
# Epoch 28/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0045 - accuracy: 0.9998 - val_loss: 0.2899 - val_accuracy: 0.9288
# Epoch 29/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9281
# Epoch 30/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9996 - val_loss: 0.2513 - val_accuracy: 0.9295
# Epoch 31/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9359
# Epoch 32/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9430
# Epoch 33/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9366
# Epoch 34/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9466
# Epoch 35/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.9509
# Epoch 36/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9544
# Epoch 37/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9580
# Epoch 38/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.1083 - val_accuracy: 0.9623
# Epoch 39/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9608
# Epoch 40/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9608
# Epoch 41/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9665
# Epoch 42/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9694
# Epoch 43/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9715
# Epoch 44/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9694
# Epoch 45/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 0.9687
# Epoch 46/100
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9708
# Epoch 47/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 0.9694
# Epoch 48/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0818 - val_accuracy: 0.9687
# Epoch 49/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9708
# Epoch 50/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9729
# Epoch 51/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9736
# Epoch 52/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0783 - val_accuracy: 0.9708
# Epoch 53/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9758
# Epoch 54/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9779
# Epoch 55/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0693 - val_accuracy: 0.9772
# Epoch 56/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9736
# Epoch 57/100
# 466/466 [==============================] - 1s 2ms/step - loss: 9.2108e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9758
# Epoch 58/100
# 466/466 [==============================] - 1s 2ms/step - loss: 9.0543e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9758
# Epoch 59/100
# 466/466 [==============================] - 1s 2ms/step - loss: 9.3243e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9765
# Epoch 60/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9786
# Epoch 61/100
# 466/466 [==============================] - 1s 2ms/step - loss: 9.1143e-04 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9729
# Epoch 62/100
# 466/466 [==============================] - 1s 2ms/step - loss: 9.3379e-04 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9772
# Epoch 63/100
# 466/466 [==============================] - 1s 2ms/step - loss: 8.1444e-04 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9758
# Epoch 64/100
# 466/466 [==============================] - 1s 2ms/step - loss: 7.1100e-04 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9751
# Epoch 65/100
# 466/466 [==============================] - 1s 2ms/step - loss: 7.8353e-04 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9758
# Epoch 66/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.9586e-04 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9751
# Epoch 67/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.5050e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9736
# Epoch 68/100
# 466/466 [==============================] - 1s 2ms/step - loss: 7.9620e-04 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9744
# Epoch 69/100
# 466/466 [==============================] - 1s 2ms/step - loss: 9.3781e-04 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9751
# Epoch 70/100
# 466/466 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9736
# Epoch 71/100
# 466/466 [==============================] - 1s 2ms/step - loss: 8.5031e-04 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9715
# Epoch 72/100
# 466/466 [==============================] - 1s 3ms/step - loss: 8.1579e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9765
# Epoch 73/100
# 466/466 [==============================] - 1s 3ms/step - loss: 7.8298e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9765
# Epoch 74/100
# 466/466 [==============================] - 1s 2ms/step - loss: 8.1737e-04 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9772
# Epoch 75/100
# 466/466 [==============================] - 1s 2ms/step - loss: 8.0175e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9687
# Epoch 76/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.5389e-04 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9744
# Epoch 77/100
# 466/466 [==============================] - 1s 2ms/step - loss: 5.9632e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9772
# Epoch 78/100
# 466/466 [==============================] - 1s 2ms/step - loss: 5.8154e-04 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9765
# Epoch 79/100
# 466/466 [==============================] - 1s 2ms/step - loss: 7.5588e-04 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9786
# Epoch 80/100
# 466/466 [==============================] - 1s 2ms/step - loss: 5.4660e-04 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9772
# Epoch 81/100
# 466/466 [==============================] - 1s 2ms/step - loss: 5.7108e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9751
# Epoch 82/100
# 466/466 [==============================] - 1s 2ms/step - loss: 5.9512e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9736
# Epoch 83/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.2456e-04 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9772
# Epoch 84/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.2141e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9765
# Epoch 85/100
# 466/466 [==============================] - 1s 2ms/step - loss: 5.1109e-04 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9765
# Epoch 86/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.0138e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9744
# Epoch 87/100
# 466/466 [==============================] - 1s 2ms/step - loss: 7.7584e-04 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9729
# Epoch 88/100
# 466/466 [==============================] - 1s 2ms/step - loss: 8.6610e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9765
# Epoch 89/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.1009e-04 - accuracy: 1.0000 - val_loss: 0.0703 - val_accuracy: 0.9786
# Epoch 90/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.4566e-04 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9758
# Epoch 91/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.4827e-04 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9758
# Epoch 92/100
# 466/466 [==============================] - 1s 2ms/step - loss: 6.3183e-04 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9701
# Epoch 93/100
# 466/466 [==============================] - 1s 2ms/step - loss: 4.7641e-04 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9701
# Epoch 94/100
# 466/466 [==============================] - 1s 2ms/step - loss: 4.6093e-04 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9744
# Epoch 95/100
# 466/466 [==============================] - 1s 3ms/step - loss: 4.3523e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9772
# Epoch 96/100
# 466/466 [==============================] - 1s 2ms/step - loss: 4.6093e-04 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9736
# Epoch 97/100
# 466/466 [==============================] - 1s 2ms/step - loss: 4.3556e-04 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9758
# Epoch 98/100
# 466/466 [==============================] - 1s 2ms/step - loss: 3.6315e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9744
# Epoch 99/100
# 466/466 [==============================] - 1s 2ms/step - loss: 3.7149e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9744
# Epoch 100/100
# 466/466 [==============================] - 1s 3ms/step - loss: 3.1970e-04 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9736

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,10))

ax1.plot(fit_results.history['loss'], label='Training')
ax1.plot(fit_results.history['val_loss'], label='Validation')
ax1.legend()
ax1.set_title('Loss')

ax2.plot(fit_results.history['accuracy'], label='Training')
ax2.plot(fit_results.history['val_accuracy'], label='Validation')
ax2.legend()
ax2.set_title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
model.save('AnimalSounds_SmallerVGGNet.h5')

f = open("AS_VGGN.pickle", "wb")
f.write(pickle.dumps(mlb))
f.close()
