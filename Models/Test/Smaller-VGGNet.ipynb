# %% [markdown]
# ### Model 2

# %%
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
class SmallerVGGNet:
    @staticmethod
    def build(width, height, depth, classes, finalAct="softmax"):
        # initialize the model along with the input shape to be
        # "channels last" and the channels dimension itself
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = 3
        
        # CONV => RELU => POOL
        model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(3, 3)))
        model.add(Dropout(0.25))

        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        
        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(128, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(128, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        
        # first (and only) set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation("relu"))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))
        
        model.add(Dense(classes))
        model.add(Activation(finalAct))
        # return the constructed network architecture
        return model

# %%
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import pickle
import cv2
import os

# %%
EPOCHS = 175
INIT_LR = 1e-3
BS = 32
IMAGE_DIMS = (96, 96, 3)

# %%
imagePaths = []
for dirname, _, filenames in os.walk(r'/kaggle/input/dataset/'):
    for filename in filenames:
        imagePaths.append(os.path.join(dirname, filename))
        
imagePaths = sorted(imagePaths)
random.seed(42)
random.shuffle(imagePaths)

# %%
data = []
labels = []

for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data.append(image)
    
    l = label = imagePath.split(os.path.sep)[-2]
    labels.append((l,))
    
labels[0:5]
# Out:
# [('Knock',),
#  ('Knock',),
#  ('Zipper_(clothing)',),
#  ('Accordion',),
#  ('Bicycle_bell',)]

# %%
print(len(data))
print(len(labels))
# Out:
# 12002
# 12002

# %%
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels) 

mlb = MultiLabelBinarizer() 
labels = mlb.fit_transform(labels) 
mlb.classes_
# Out:
# array(['Accelerating_and_revving_and_vroom', 'Accordion',
#        'Acoustic_guitar', 'Applause', 'Bark', 'Bass_drum', 'Bass_guitar',
#        'Bathtub_(filling_or_washing)', 'Bicycle_bell',
#        'Burping_and_eructation', 'Bus', 'Buzz', 'Car_passing_by',
#        'Cheering', 'Chewing_and_mastication',
#        'Child_speech_and_kid_speaking', 'Chink_and_clink',
#        'Chirp_and_tweet', 'Church_bell', 'Clapping', 'Computer_keyboard',
#        'Crackle', 'Cricket', 'Crowd', 'Cupboard_open_or_close',
#        'Cutlery_and_silverware', 'Dishes_and_pots_and_pans',
#        'Drawer_open_or_close', 'Drip', 'Electric_guitar', 'Fart',
#        'Female_singing', 'Female_speech_and_woman_speaking',
#        'Fill_(with_liquid)', 'Finger_snapping', 'Frying_(food)', 'Gasp',
#        'Glockenspiel', 'Gong', 'Gurgling', 'Harmonica', 'Hi-hat', 'Hiss',
#        'Keys_jangling', 'Knock', 'Male_singing',
#        'Male_speech_and_man_speaking', 'Marimba_and_xylophone',
#        'Mechanical_fan', 'Meow', 'Microwave_oven', 'Motorcycle',
#        'Printer', 'Purr', 'Race_car_and_auto_racing', 'Raindrop', 'Run',
#        'Scissors', 'Screaming', 'Shatter', 'Sigh',
#        'Sink_(filling_or_washing)', 'Skateboard', 'Slam', 'Sneeze',
#        'Squeak', 'Stream', 'Strum', 'Tap', 'Tick-tock', 'Toilet_flush',
#        'Traffic_noise_and_roadway_noise', 'Trickle_and_dribble',
#        'Walk_and_footsteps', 'Water_tap_and_faucet', 'Waves_and_surf',
#        'Whispering', 'Writing', 'Yell', 'Zipper_(clothing)'], dtype=object)

# %%
(train_X, valid_X, train_y, valid_y) = train_test_split(data, labels, test_size=0.2, random_state=2018)

# %%
model = SmallerVGGNet.build(
    width = IMAGE_DIMS[1],
    height = IMAGE_DIMS[0],
    depth = IMAGE_DIMS[2],
    classes = len(mlb.classes_),
    finalAct = "sigmoid"
)

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR/EPOCHS)

# %%
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

print("Training network...")

H = model.fit(
    train_X, train_y,
    epochs = EPOCHS,
    batch_size = BS,
    validation_data = (valid_X, valid_y),
    verbose=1
)
# Out:
# Training network...
# Train on 9601 samples, validate on 2401 samples
# Epoch 1/175
# 9601/9601 [==============================] - 14s 2ms/step - loss: 0.2312 - accuracy: 0.9067 - val_loss: 0.0811 - val_accuracy: 0.9869
# Epoch 2/175
# 9601/9601 [==============================] - 8s 882us/step - loss: 0.0584 - accuracy: 0.9869 - val_loss: 0.0587 - val_accuracy: 0.9874
# Epoch 3/175
# 9601/9601 [==============================] - 8s 864us/step - loss: 0.0516 - accuracy: 0.9871 - val_loss: 0.0493 - val_accuracy: 0.9875
# Epoch 4/175
# 9601/9601 [==============================] - 8s 871us/step - loss: 0.0484 - accuracy: 0.9875 - val_loss: 0.0492 - val_accuracy: 0.9869
# Epoch 5/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0448 - accuracy: 0.9878 - val_loss: 0.0574 - val_accuracy: 0.9861
# Epoch 6/175
# 9601/9601 [==============================] - 8s 882us/step - loss: 0.0417 - accuracy: 0.9883 - val_loss: 0.0431 - val_accuracy: 0.9882
# Epoch 7/175
# 9601/9601 [==============================] - 9s 918us/step - loss: 0.0399 - accuracy: 0.9885 - val_loss: 0.0424 - val_accuracy: 0.9882
# Epoch 8/175
# 9601/9601 [==============================] - 8s 876us/step - loss: 0.0388 - accuracy: 0.9886 - val_loss: 0.0507 - val_accuracy: 0.9869
# Epoch 9/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0373 - accuracy: 0.9887 - val_loss: 0.0448 - val_accuracy: 0.9878
# Epoch 10/175
# 9601/9601 [==============================] - 8s 883us/step - loss: 0.0353 - accuracy: 0.9892 - val_loss: 0.0677 - val_accuracy: 0.9859
# Epoch 11/175
# 9601/9601 [==============================] - 8s 877us/step - loss: 0.0365 - accuracy: 0.9889 - val_loss: 0.0582 - val_accuracy: 0.9877
# Epoch 12/175
# 9601/9601 [==============================] - 8s 871us/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 1.3645 - val_accuracy: 0.9195
# Epoch 13/175
# 9601/9601 [==============================] - 9s 889us/step - loss: 0.0381 - accuracy: 0.9885 - val_loss: 0.0459 - val_accuracy: 0.9882
# Epoch 14/175
# 9601/9601 [==============================] - 9s 954us/step - loss: 0.0324 - accuracy: 0.9895 - val_loss: 0.0419 - val_accuracy: 0.9885
# Epoch 15/175
# 9601/9601 [==============================] - 9s 912us/step - loss: 0.0304 - accuracy: 0.9901 - val_loss: 0.0438 - val_accuracy: 0.9880
# Epoch 16/175
# 9601/9601 [==============================] - 8s 880us/step - loss: 0.0278 - accuracy: 0.9905 - val_loss: 0.0571 - val_accuracy: 0.9876
# Epoch 17/175
# 9601/9601 [==============================] - 9s 887us/step - loss: 0.0267 - accuracy: 0.9906 - val_loss: 0.5506 - val_accuracy: 0.9750
# Epoch 18/175
# 9601/9601 [==============================] - 9s 898us/step - loss: 0.0256 - accuracy: 0.9910 - val_loss: 0.0585 - val_accuracy: 0.9872
# Epoch 19/175
# 9601/9601 [==============================] - 8s 882us/step - loss: 0.0248 - accuracy: 0.9913 - val_loss: 0.0554 - val_accuracy: 0.9866
# Epoch 20/175
# 9601/9601 [==============================] - 8s 883us/step - loss: 0.0260 - accuracy: 0.9908 - val_loss: 0.0568 - val_accuracy: 0.9862
# Epoch 21/175
# 9601/9601 [==============================] - 9s 951us/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 0.0578 - val_accuracy: 0.9858
# Epoch 22/175
# 9601/9601 [==============================] - 9s 912us/step - loss: 0.0234 - accuracy: 0.9916 - val_loss: 0.1637 - val_accuracy: 0.9805
# Epoch 23/175
# 9601/9601 [==============================] - 9s 888us/step - loss: 0.0224 - accuracy: 0.9918 - val_loss: 0
step - loss: 0.0120 - accuracy: 0.9949 - val_loss: 0.0608 - val_accuracy: 0.9859
# Epoch 73/175
# 9601/9601 [==============================] - 8s 877us/step - loss: 0.0121 - accuracy: 0.9947 - val_loss: 0.0589 - val_accuracy: 0.9861
# Epoch 74/175
# 9601/9601 [==============================] - 8s 881us/step - loss: 0.0121 - accuracy: 0.9948 - val_loss: 0.0624 - val_accuracy: 0.9859
# Epoch 75/175
# 9601/9601 [==============================] - 9s 891us/step - loss: 0.0121 - accuracy: 0.9948 - val_loss: 0.0598 - val_accuracy: 0.9863
# Epoch 76/175
# 9601/9601 [==============================] - 9s 931us/step - loss: 0.0119 - accuracy: 0.9949 - val_loss: 0.0628 - val_accuracy: 0.9862
# Epoch 77/175
# 9601/9601 [==============================] - 9s 892us/step - loss: 0.0120 - accuracy: 0.9948 - val_loss: 0.0614 - val_accuracy: 0.9862
# Epoch 78/175
# 9601/9601 [==============================] - 8s 885us/step - loss: 0.0117 - accuracy: 0.9948 - val_loss: 0.0628 - val_accuracy: 0.9861
# Epoch 79/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0116 - accuracy: 0.9948 - val_loss: 0.0606 - val_accuracy: 0.9861
# Epoch 80/175
# 9601/9601 [==============================] - 8s 881us/step - loss: 0.0117 - accuracy: 0.9949 - val_loss: 0.0631 - val_accuracy: 0.9862
# Epoch 81/175
# 9601/9601 [==============================] - 8s 881us/step - loss: 0.0117 - accuracy: 0.9948 - val_loss: 0.0613 - val_accuracy: 0.9862
# Epoch 82/175
# 9601/9601 [==============================] - 9s 888us/step - loss: 0.0117 - accuracy: 0.9948 - val_loss: 0.0601 - val_accuracy: 0.9859
# Epoch 83/175
# 9601/9601 [==============================] - 9s 909us/step - loss: 0.0115 - accuracy: 0.9949 - val_loss: 0.0605 - val_accuracy: 0.9863
# Epoch 84/175
# 9601/9601 [==============================] - 9s 896us/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 0.0625 - val_accuracy: 0.9863
# Epoch 85/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0114 - accuracy: 0.9949 - val_loss: 0.0605 - val_accuracy: 0.9860
# Epoch 86/175
# 9601/9601 [==============================] - 9s 889us/step - loss: 0.0114 - accuracy: 0.9949 - val_loss: 0.0627 - val_accuracy: 0.9860
# Epoch 87/175
# 9601/9601 [==============================] - 8s 872us/step - loss: 0.0115 - accuracy: 0.9949 - val_loss: 0.0584 - val_accuracy: 0.9861
# Epoch 88/175
# 9601/9601 [==============================] - 8s 876us/step - loss: 0.0116 - accuracy: 0.9948 - val_loss: 0.0600 - val_accuracy: 0.9862
# Epoch 89/175
# 9601/9601 [==============================] - 8s 871us/step - loss: 0.0113 - accuracy: 0.9950 - val_loss: 0.0646 - val_accuracy: 0.9863
# Epoch 90/175
# 9601/9601 [==============================] - 9s 936us/step - loss: 0.0113 - accuracy: 0.9949 - val_loss: 0.0605 - val_accuracy: 0.9859
# Epoch 91/175
# 9601/9601 [==============================] - 9s 893us/step - loss: 0.0111 - accuracy: 0.9950 - val_loss: 0.0618 - val_accuracy: 0.9860
# Epoch 92/175
# 9601/9601 [==============================] - 8s 866us/step - loss: 0.0111 - accuracy: 0.9949 - val_loss: 0.0606 - val_accuracy: 0.9859
# Epoch 93/175
# 9601/9601 [==============================] - 8s 874us/step - loss: 0.0113 - accuracy: 0.9950 - val_loss: 0.0657 - val_accuracy: 0.9870
# Epoch 94/175
# 9601/9601 [==============================] - 9s 887us/step - loss: 0.0111 - accuracy: 0.9949 - val_loss: 0.0630 - val_accuracy: 0.9862
# Epoch 95/175
# 9601/9601 [==============================] - 8s 879us/step - loss: 0.0113 - accuracy: 0.9948 - val_loss: 0.0626 - val_accuracy: 0.9865
# Epoch 96/175
# 9601/9601 [==============================] - 8s 867us/step - loss: 0.0109 - accuracy: 0.9950 - val_loss: 0.0640 - val_accuracy: 0.9861
# Epoch 97/175
# 9601/9601 [==============================] - 9s 937us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0623 - val_accuracy: 0.9859
# Epoch 98/175
# 9601/9601 [==============================] - 9s 898us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0622 - val_accuracy: 0.9859
# Epoch 99/175
# 9601/9601 [==============================] - 8s 874us/step - loss: 0.0110 - accuracy: 0.9949 - val_loss: 0.0610 - val_accuracy: 0.9862
# Epoch 100/175
# 9601/9601 [==============================] - 8s 874us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0620 - val_accuracy: 0.9860
# Epoch 101/175
# 9601/9601 [==============================] - 8s 873us/step - loss: 0.0108 - accuracy: 0.9951 - val_loss: 0.0610 - val_accuracy: 0.9861
# Epoch 102/175
# 9601/9601 [==============================] - 9s 893us/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 0.0634 - val_accuracy: 0.9860
# Epoch 103/175
# 9601/9601 [==============================] - 9s 886us/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 0.0639 - val_accuracy: 0.9863
# Epoch 104/175
# 9601/9601 [==============================] - 9s 918us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0628 - val_accuracy: 0.9860
# Epoch 105/175
# 9601/9601 [==============================] - 9s 889us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0611 - val_accuracy: 0.9860
# Epoch 106/175
# 9601/9601 [==============================] - 8s 881us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0614 - val_accuracy: 0.9859
# Epoch 107/175
# 9601/9601 [==============================] - 8s 877us/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.0633 - val_accuracy: 0.9859
# Epoch 108/175
# 9601/9601 [==============================] - 8s 872us/step - loss: 0.0106 - accuracy: 0.9950 - val_loss: 0.0641 - val_accuracy: 0.9860
# Epoch 109/175
# 9601/9601 [==============================] - 8s 882us/step - loss: 0.0107 - accuracy: 0.9950 - val_loss: 0.0574 - val_accuracy: 0.9862
# Epoch 110/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0104 - accuracy: 0.9951 - val_loss: 0.0631 - val_accuracy: 0.9863
# Epoch 111/175
# 9601/9601 [==============================] - 9s 905us/step - loss: 0.0105 - accuracy: 0.9951 - val_loss: 0.0599 - val_accuracy: 0.9861
# Epoch 112/175
# 9601/9601 [==============================] - 9s 899us/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 0.0617 - val_accuracy: 0.9860
# Epoch 113/175
# 9601/9601 [==============================] - 9s 891us/step - loss: 0.0106 - accuracy: 0.9950 - val_loss: 0.0664 - val_accuracy: 0.9861
# Epoch 114/175
# 9601/9601 [==============================] - 8s 865us/step - loss: 0.0105 - accuracy: 0.9950 - val_loss: 0.0624 - val_accuracy: 0.9865
# Epoch 115/175
# 9601/9601 [==============================] - 8s 877us/step - loss: 0.0105 - accuracy: 0.9950 - val_loss: 0.0600 - val_accuracy: 0.9860
# Epoch 116/175
# 9601/9601 [==============================] - 9s 894us/step - loss: 0.0103 - accuracy: 0.9951 - val_loss: 0.0623 - val_accuracy: 0.9862
# Epoch 117/175
# 9601/9601 [==============================] - 9s 913us/step - loss: 0.0102 - accuracy: 0.9951 - val_loss: 0.0622 - val_accuracy: 0.9861
# Epoch 118/175
# 9601/9601 [==============================] - 9s 921us/step - loss: 0.0103 - accuracy: 0.9950 - val_loss: 0.0617 - val_accuracy: 0.9860
# Epoch 119/175
# 9601/9601 [==============================] - 9s 913us/step - loss: 0.0105 - accuracy: 0.9950 - val_loss: 0.0619 - val_accuracy: 0.9859
# Epoch 120/175
# 9601/9601 [==============================] - 9s 906us/step - loss: 0.0103 - accuracy: 0.9951 - val_loss: 0.0630 - val_accuracy: 0.9860
# Epoch 121/175
# 9601/9601 [==============================] - 9s 892us/step - loss: 0.0104 - accuracy: 0.9951 - val_loss: 0.0627 - val_accuracy: 0.9860
# Epoch 122/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0102 - accuracy: 0.9951 - val_loss: 0.0617 - val_accuracy: 0.9860
# Epoch 123/175
# 9601/9601 [==============================] - 8s 866us/step - loss: 0.0102 - accuracy: 0.9951 - val_loss: 0.0634 - val_accuracy: 0.9862
# Epoch 124/175
# 9601/9601 [==============================] - 8s 877us/step - loss: 0.0101 - accuracy: 0.9951 - val_loss: 0.0629 - val_accuracy: 0.9858
# Epoch 125/175
# 9601/9601 [==============================] - 9s 938us/step - loss: 0.0101 - accuracy: 0.9951 - val_loss: 0.0637 - val_accuracy: 0.9859
# Epoch 126/175
# 9601/9601 [==============================] - 8s 885us/step - loss: 0.0101 - accuracy: 0.9951 - val_loss: 0.0613 - val_accuracy: 0.9862
# Epoch 127/175
# 9601/9601 [==============================] - 8s 880us/step - loss: 0.0101 - accuracy: 0.9951 - val_loss: 0.0642 - val_accuracy: 0.9860
# Epoch 128/175
# 9601/9601 [==============================] - 8s 874us/step - loss: 0.0100 - accuracy: 0.9951 - val_loss: 0.0635 - val_accuracy: 0.9860
# Epoch 129/175
# 9601/9601 [==============================] - 8s 881us/step - loss: 0.0102 - accuracy: 0.9951 - val_loss: 0.0634 - val_accuracy: 0.9862
# Epoch 130/175
# 9601/9601 [==============================] - 8s 871us/step - loss: 0.0100 - accuracy: 0.9951 - val_loss: 0.0599 - val_accuracy: 0.9860
# Epoch 131/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0100 - accuracy: 0.9952 - val_loss: 0.0620 - val_accuracy: 0.9860
# Epoch 132/175
# 9601/9601 [==============================] - 9s 905us/step - loss: 0.0099 - accuracy: 0.9951 - val_loss: 0.0615 - val_accuracy: 0.9860
# Epoch 133/175
# 9601/9601 [==============================] - 9s 891us/step - loss: 0.0099 - accuracy: 0.9952 - val_loss: 0.0629 - val_accuracy: 0.9861
# Epoch 134/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0098 - accuracy: 0.9953 - val_loss: 0.0643 - val_accuracy: 0.9861
# Epoch 135/175
# 9601/9601 [==============================] - 8s 878us/step - loss: 0.0100 - accuracy: 0.9951 - val_loss: 0.0628 - val_accuracy: 0.9860
# Epoch 136/175
# 9601/9601 [==============================] - 8s 874us/step - loss: 0.0099 - accuracy: 0.9951 - val_loss: 0.0626 - val_accuracy: 0.9860
# Epoch 137/175
# 9601/9601 [==============================] - 8s 872us/step - loss: 0.0099 - accuracy: 0.9952 - val_loss: 0.0645 - val_accuracy: 0.9862
# Epoch 138/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0099 - accuracy: 0.9951 - val_loss: 0.0655 - val_accuracy: 0.9863
# Epoch 139/175
# 9601/9601 [==============================] - 9s 916us/step - loss: 0.0099 - accuracy: 0.9951 - val_loss: 0.0651 - val_accuracy: 0.9861
# Epoch 140/175
# 9601/9601 [==============================] - 9s 913us/step - loss: 0.0099 - accuracy: 0.9952 - val_loss: 0.0652 - val_accuracy: 0.9860
# Epoch 141/175
# 9601/9601 [==============================] - 8s 864us/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.0624 - val_accuracy: 0.9860
# Epoch 142/175
# 9601/9601 [==============================] - 8s 872us/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.0655 - val_accuracy: 0.9858
# Epoch 143/175
# 9601/9601 [==============================] - 8s 867us/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.0640 - val_accuracy: 0.9860
# Epoch 144/175
# 9601/9601 [==============================] - 9s 887us/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.0656 - val_accuracy: 0.9860
# Epoch 145/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.0640 - val_accuracy: 0.9860
# Epoch 146/175
# 9601/9601 [==============================] - 9s 902us/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 0.0652 - val_accuracy: 0.9862
# Epoch 147/175
# 9601/9601 [==============================] - 9s 902us/step - loss: 0.0096 - accuracy: 0.9953 - val_loss: 0.0639 - val_accuracy: 0.9863
# Epoch 148/175
# 9601/9601 [==============================] - 9s 893us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0644 - val_accuracy: 0.9861
# Epoch 149/175
# 9601/9601 [==============================] - 8s 863us/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 0.0631 - val_accuracy: 0.9859
# Epoch 150/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 0.0649 - val_accuracy: 0.9859
# Epoch 151/175
# 9601/9601 [==============================] - 8s 871us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0648 - val_accuracy: 0.9859
# Epoch 152/175
# 9601/9601 [==============================] - 9s 885us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0641 - val_accuracy: 0.9861
# Epoch 153/175
# 9601/9601 [==============================] - 9s 914us/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 0.0649 - val_accuracy: 0.9860
# Epoch 154/175
# 9601/9601 [==============================] - 9s 903us/step - loss: 0.0095 - accuracy: 0.9953 - val_loss: 0.0610 - val_accuracy: 0.9859
# Epoch 155/175
# 9601/9601 [==============================] - 8s 874us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0658 - val_accuracy: 0.9860
# Epoch 156/175
# 9601/9601 [==============================] - 8s 880us/step - loss: 0.0095 - accuracy: 0.9952 - val_loss: 0.0649 - val_accuracy: 0.9862
# Epoch 157/175
# 9601/9601 [==============================] - 8s 876us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0659 - val_accuracy: 0.9861
# Epoch 158/175
# 9601/9601 [==============================] - 8s 865us/step - loss: 0.0095 - accuracy: 0.9953 - val_loss: 0.0634 - val_accuracy: 0.9860
# Epoch 159/175
# 9601/9601 [==============================] - 8s 877us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0625 - val_accuracy: 0.9858
# Epoch 160/175
# 9601/9601 [==============================] - 9s 907us/step - loss: 0.0095 - accuracy: 0.9952 - val_loss: 0.0652 - val_accuracy: 0.9859
# Epoch 161/175
# 9601/9601 [==============================] - 9s 906us/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0639 - val_accuracy: 0.9860
# Epoch 162/175
# 9601/9601 [==============================] - 8s 865us/step - loss: 0.0094 - accuracy: 0.9953 - val_loss: 0.0649 - val_accuracy: 0.9858
# Epoch 163/175
# 9601/9601 [==============================] - 8s 878us/step - loss: 0.0095 - accuracy: 0.9953 - val_loss: 0.0634 - val_accuracy: 0.9862
# Epoch 164/175
# 9601/9601 [==============================] - 8s 884us/step - loss: 0.0093 - accuracy: 0.9953 - val_loss: 0.0638 - val_accuracy: 0.9862
# Epoch 165/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0095 - accuracy: 0.9952 - val_loss: 0.0680 - val_accuracy: 0.9861
# Epoch 166/175
# 9601/9601 [==============================] - 8s 867us/step - loss: 0.0093 - accuracy: 0.9954 - val_loss: 0.0634 - val_accuracy: 0.9861
# Epoch 167/175
# 9601/9601 [==============================] - 9s 900us/step - loss: 0.0095 - accuracy: 0.9952 - val_loss: 0.0643 - val_accuracy: 0.9859
# Epoch 168/175
# 9601/9601 [==============================] - 9s 911us/step - loss: 0.0094 - accuracy: 0.9952 - val_loss: 0.0625 - val_accuracy: 0.9861
# Epoch 169/175
# 9601/9601 [==============================] - 8s 872us/step - loss: 0.0094 - accuracy: 0.9952 - val_loss: 0.0647 - val_accuracy: 0.9859
# Epoch 170/175
# 9601/9601 [==============================] - 8s 871us/step - loss: 0.0092 - accuracy: 0.9954 - val_loss: 0.0647 - val_accuracy: 0.9859
# Epoch 171/175
# 9601/9601 [==============================] - 8s 875us/step - loss: 0.0093 - accuracy: 0.9953 - val_loss: 0.0645 - val_accuracy: 0.9860
# Epoch 172/175
# 9601/9601 [==============================] - 8s 870us/step - loss: 0.0094 - accuracy: 0.9952 - val_loss: 0.0625 - val_accuracy: 0.9859
# Epoch 173/175
# 9601/9601 [==============================] - 8s 873us/step - loss: 0.0092 - accuracy: 0.9953 - val_loss: 0.0654 - val_accuracy: 0.9861
# Epoch 174/175
# 9601/9601 [==============================] - 9s 896us/step - loss: 0.0092 - accuracy: 0.9953 - val_loss: 0.0675 - val_accuracy: 0.9862
# Epoch 175/175
# 9601/9601 [==============================] - 9s 925us/step - loss: 0.0093 - accuracy: 0.9953 - val_loss: 0.0651 - val_accuracy: 0.9860

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

ax1.plot(H.history['loss'], label='Training loss')
ax1.plot(H.history['val_loss'], label='Validation loss')
ax1.legend()
ax1.set_title('Loss')

ax2.plot(H.history["accuracy"], label='Training accuracy')
ax2.plot(H.history["val_accuracy"], label='Validation accuracy')
ax2.legend()
ax2.set_title('Accuracy')
ax2.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
model.save('svggnet.h5')

f = open("mlb.pickle", "wb")
f.write(pickle.dumps(mlb))
f.close()
